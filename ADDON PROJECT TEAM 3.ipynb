# %% [markdown]
# <a href="https://colab.research.google.com/github/aron702/Car/blob/main/ADDON%20PROJECT%20TEAM%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel('/content/Updated_PROJECT_Y.xlsx')
df.head()
# Out:
#    APP NO           NAME   AGE GENDER    LOCATION  Unnamed: 5      ATHLETICS  \
# 0       1  JOSEPH CHACKO  20.0   MALE  MALAPPURAM         NaN  1500M RUNNING
# 1       2      SIBIN SAM  20.0   MALE       RANNI         NaN  1500M RUNNING
# 2       3    ADITHYAN KS  21.0   MALE      MUNNAR         NaN  1500M RUNNING
# 3       4     SEBIN BIJU  22.0   MALE        PALA         NaN  1500M RUNNING
# 4       5      DANI SEVI  22.0   MALE  KARUKACHAL         NaN  1500M RUNNING
#
#    Unnamed: 7         BATCH  YEAR GRADE
# 0         NaN    BCA 2 YEAR  2024     A
# 1         NaN    BCA 2 YEAR  2024     B
# 2         NaN  MICRO 3 YEAR  2024     D
# 3         NaN     BA 3 YEAR  2024     C
# 4         NaN    BBA 1 YEAR  2024     D

# %%
df.describe()
# Out:
#             APP NO          AGE  Unnamed: 5  Unnamed: 7         YEAR
# count  2056.000000  2053.000000         0.0         0.0  2056.000000
# mean   1028.500000    20.981003         NaN         NaN  2024.489786
# std     593.660397     1.994664         NaN         NaN     0.508701
# min       1.000000    18.000000         NaN         NaN  2023.000000
# 25%     514.750000    19.000000         NaN         NaN  2024.000000
# 50%    1028.500000    21.000000         NaN         NaN  2024.000000
# 75%    1542.250000    23.000000         NaN         NaN  2025.000000
# max    2056.000000    30.000000         NaN         NaN  2025.000000

# %%
cdf = df[['AGE','LOCATION','GRADE','ATHLETICS']]
cdf.sample(9)
# Out:
#        AGE     LOCATION GRADE      ATHLETICS
# 1889  20.0    ERNAKULAM     B   100M RUNNING
# 1409  21.0    KOZHIKODE     B      HIGH JUMP
# 1692  21.0     THRISSUR     B  JAVELIN THROW
# 1156  20.0   TRIVANDRUM     A  JAVELIN THROW
# 37    20.0  NEDUMKUNNAM     D   500M RUNNING
# 1305  19.0    KOZHIKODE     B  JAVELIN THROW
# 556   20.0     THRISSUR     C   100M RUNNING
# 917   19.0    ERNAKULAM     C      LONG JUMP
# 1675  22.0    ERNAKULAM     A   100M RUNNING

# %%
viz = cdf[['AGE','LOCATION','GRADE','ATHLETICS']]
viz.hist()
plt.show()

# %%
plt.scatter(cdf.GRADE, cdf.AGE,  color='blue')
plt.xlabel("GRADE")
plt.ylabel("AGE")
plt.show()

# %%
plt.scatter(cdf.LOCATION, cdf.GRADE,  color='blue')
plt.xlabel("LOCATION")
plt.ylabel("GRADE")
plt.xlim(0,27)
plt.show()
